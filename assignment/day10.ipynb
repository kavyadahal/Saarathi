# %% [markdown]
# # Day 10 Revision Summary — Week 2 Capstone & Architecture Review
#
# - Day 10 is a pure **revision day** — no new syntax. The goal is consolidating Days 6–9 and honestly finding your own gaps ("Type everything; no copy-paste, and no notes where it says so").
# - The **Week 2 capstone** (`records_app.py`) chains every skill together: typed functions & comprehensions (Day 6), specific `try/except` (Day 7), `with open` + JSON + main-guard (Day 8), and classes + numpy + pandas (Day 9).
# - **Mixed drills** reinforce the recurring gotchas: a function with no `return` gives back `None` (so `g(5)` prints *two* lines — once inside the function, once from the outer `print`); type hints **don't enforce** anything at runtime (`double("ab")` doesn't crash); and `json.dumps({1: True})` turns the integer key `1` into the string `"1"`.
# - `[1, 2] * 2` **repeats** a Python list, while `np.array([1, 2]) * 2` **doubles each value** — a trap worth re-drilling.
# - The "Cursor check" upgrade for Week 2: don't just accept AI-generated code — **critique** it. Are the type hints right? Is the `except` specific or bare? Does it `return`, or just `print`?
#
# *Reference material: the homework slide points to `resources/week2_revision_sheet.md` for a self-assessment checklist (referenced, not fetched, per this notebook's scope).*

# %% [markdown]
# ## Classwork Exercise 1 — Student records app / Week 2 capstone (`records_app.py`, ~25 min)
#
# **What's being asked:** Build one small app that exercises every Week 2 skill: safely load student records (`name` + `scores` list) from `students.json`, wrap them in `Student` objects with `average()`/`grade()`/`to_dict()`, build a pandas report, print the class average, and save `report.csv`. Stretch: print only the students who passed, and add a main-guard.
#
# **Approach:**
# 1. Define `Student(name: str, scores: list[int])` with `average() -> float` (mean of scores), `grade() -> str` (A/B/C/Needs work thresholds), `passed() -> bool` (`average() >= 40`), and `to_dict() -> dict`.
# 2. Write `seed_data(path)` that writes a small JSON list of `{"name": ..., "scores": [...]}` records to `path` (only used to create sample data to load).
# 3. Write `load_students(path) -> list[Student]` wrapped in `try/except` catching `FileNotFoundError` **and** `json.JSONDecodeError`, returning `[]` on either — then a comprehension building `Student` objects from the raw list.
# 4. Write `build_report(students) -> pd.DataFrame` from `[s.to_dict() for s in students]`.
# 5. In `main()`: load the students, build the DataFrame, print it, print `df["average"].mean()` and the passed count, then `df.to_csv("report.csv", index=False)`.
# 6. Stretch: print `df[df["passed"]]` only, and wrap the whole thing in `if __name__ == "__main__":`.

# %%
# Day 10 · Classwork Exercise 1 — Student records app (Week 2 capstone)
# Source: classwork/records_app.py

import json

import numpy as np
import pandas as pd


class Student:
    def __init__(self, name: str, scores: list[int]):
        # TODO: store name and scores
        pass

    def average(self) -> float:
        # TODO: return float(np.mean(self.scores))
        pass

    def grade(self) -> str:
        # TODO: avg >= 80 -> "A", >= 60 -> "B", >= 40 -> "C", else "Needs work"
        pass

    def passed(self) -> bool:
        # TODO: return self.average() >= 40
        pass

    def to_dict(self) -> dict:
        # TODO: return {"name": ..., "average": round(self.average(), 1),
        #                "grade": self.grade(), "passed": self.passed()}
        pass


def seed_data(path: str) -> None:
    """Create the source file so the app has something to load."""
    data = [
        {"name": "Bishal", "scores": [78, 92, 55]},
        {"name": "Sita", "scores": [88, 91, 95]},
        {"name": "Ram", "scores": [34, 41, 29]},
        {"name": "Gita", "scores": [61, 70, 58]},
    ]
    # TODO: with open(path, "w") as f: json.dump(data, f, indent=2)


def load_students(path: str) -> list:
    """Return Student objects, or [] if the file is missing/malformed."""
    # TODO: try/except FileNotFoundError and json.JSONDecodeError -> return []
    # TODO: otherwise return [Student(d["name"], d["scores"]) for d in raw]
    pass


def build_report(students: list) -> pd.DataFrame:
    # TODO: rows = [s.to_dict() for s in students]; return pd.DataFrame(rows)
    pass


def main() -> None:
    path = "students.json"
    seed_data(path)

    # TODO: students = load_students(path)
    # TODO: df = build_report(students)
    # TODO: print(df)
    # TODO: print(f"Class average: {df['average'].mean():.1f}")
    # TODO: print(f"Passed: {int(df['passed'].sum())} of {len(df)}")

    # STRETCH: print(df[df["passed"]])
    # TODO: df.to_csv("report.csv", index=False)

    # TODO: confirm a missing file returns [] instead of crashing
    # print("Missing file ->", load_students("nope.json"))


# STRETCH: main-guard so this only runs when executed directly
# if __name__ == "__main__":
#     main()

# %% [markdown]
# ## Classwork Exercise 2 — Mixed drills (`mixed_drills.py`, ~12 min)
#
# **What's being asked:** For every line of a script spanning Days 6–9, write your **prediction as a comment first**, then run it and compare. Focus areas called out explicitly: `g(5)` printing **two** lines (return vs print), `double("ab")` **not** crashing (hints don't enforce), and `json.dumps({1: True})` (keys become strings).
#
# **Approach:**
# 1. Read each snippet one block at a time: `f(3)`, `f(3, 3)`, `f(3, 3, 9, 9)` (defaults + `*args`); `g(5)` (return vs print); list/dict comprehensions; `double("ab")` (hints don't enforce); `int("3.5")` (which exception is raised); `json.dumps({1: True})` and `json.loads(...)`; `[1, 2] * 2` vs `np.array([1, 2]) * 2`; `a.mean()` and `a[a > 15]`.
# 2. Before running, write `# predict: <your guess>` next to each `print(...)` call.
# 3. Run the script and compare the actual output to your prediction.
# 4. For every wrong prediction, write one sentence explaining the mismatch — that becomes your weekend revision list.

# %%
# Day 10 · Classwork Exercise 2 — Mixed drills (predict, then run)
# Source: classwork/mixed_drills.py
# Write your PREDICTION as a comment next to each line FIRST, then run and check.

import json

import numpy as np


# --- Day 6: functions, defaults, *args ---
def f(a, b=2, *args):
    return a * b + len(args)


print(f(3))  # TODO predict:
print(f(3, 3))  # TODO predict:
print(f(3, 3, 9, 9))  # TODO predict:


# --- Day 6: return vs print (the classic) ---
def g(x):
    print(x * 2)


result = g(5)
print(result)  # TODO predict: (two lines printed - why?)


# --- Day 6: comprehensions ---
print([n for n in range(6) if n % 2])  # TODO predict:
print({w: len(w) for w in ["ai", "rag"]})  # TODO predict:


# --- Day 7: type hints don't enforce ---
def double(x: int) -> int:
    return x * 2


print(double("ab"))  # TODO predict: does this crash?


# --- Day 7: catching the right error ---
try:
    n = int("3.5")
except ValueError as e:
    print("caught:", type(e).__name__)  # TODO predict:


# --- Day 8: JSON gotchas ---
print(json.dumps({1: True}))  # TODO predict:
print(type(json.loads('{"a": 1}')))  # TODO predict:


# --- Day 9: list vs array ---
print([1, 2] * 2)  # TODO predict:
print(np.array([1, 2]) * 2)  # TODO predict:

a = np.array([10, 20, 30])
print(a.mean(), a[a > 15])  # TODO predict:

# %% [markdown]
# ## Classwork Exercise 3 — Cursor critique: the Week 2 upgrade (~discussion, no fixed source file)
#
# **What's being asked:** Let Cursor/an AI assistant autocomplete a small function, then **critique** — not just accept — its output. Week 1's rule was "explain what you accept"; Week 2 raises it to "judge whether it's any good".
#
# **Approach:**
# 1. Write a one-line docstring/comment describing a small function you want (e.g. "parse an int from a string, return `None` on failure").
# 2. Let the AI autocomplete the function body.
# 3. Check the type hints against what the function actually does.
# 4. Check whether `except` is specific (e.g. `ValueError`) or a bare `except:`.
# 5. Check whether the function actually `return`s the result, or just `print`s it.
# 6. Rewrite/fix anything that fails the checklist, and note what you changed.

# %%
# Day 10 · Classwork Exercise 3 — Cursor critique checklist
# No fixed source file; this is a judgement exercise, sketched as a runnable checklist.

# TODO: paste (or write) the AI-suggested function here, e.g.:
# def parse_int(s: str) -> int:
#     return int(s)


def critique(fn) -> None:
    """Run through the Week-2 checklist against a function you (or Cursor) wrote."""
    # TODO 1: Are the type hints on `fn` actually correct for what it does?
    # TODO 2: Does `fn` use a specific except clause, or a bare `except:`?
    # TODO 3: Does `fn` `return` its result, or does it just `print` it?
    # TODO 4: Write one sentence per answer as a comment below.
    pass


# TODO: call critique() on your AI-suggested function and record your findings

# %% [markdown]
# ## Homework Exercise 4 — Rebuild one program per day, from memory (~weekend)
#
# **What's being asked:** Without looking at your old code, rebuild one small program from each day of Week 2 (Days 6, 7, 8, 9) purely from memory, to prove you retained the material rather than copy-pasted your way through it.
#
# **Approach:**
# 1. Day 6: rewrite a function that uses `*args`/`**kwargs` and a comprehension.
# 2. Day 7: rewrite a function with type hints and a `try/except` that raises a custom exception.
# 3. Day 8: rewrite a small JSON load/save script with a main-guard.
# 4. Day 9: rewrite a small class with at least one method, and reuse it with numpy/pandas.
# 5. Compare each rebuild against your original code from that day — note anything you got wrong or forgot.

# %%
# Day 10 · Homework Exercise 4 — Rebuild one Week 2 program per day, from memory
# Open-ended: pick ONE small program per day and rebuild it without looking at your old code.

# --- Day 6 rebuild: a function using *args/**kwargs + a comprehension ---
# TODO: write it from memory


# --- Day 7 rebuild: typed function + try/except raising a custom exception ---
# TODO: write it from memory


# --- Day 8 rebuild: JSON load/save script with a main-guard ---
# TODO: write it from memory


# --- Day 9 rebuild: a small class with one method, used with numpy/pandas ---
# TODO: write it from memory


# TODO: for each rebuild, add a comment noting what you got wrong vs. your original

# %% [markdown]
# ## Other homework items (no code needed)
#
# - Work through `resources/week2_revision_sheet.md` and tick off its self-assessment checklist.
# - Commit your work: `git add . && git commit -m "week 2 complete"`.

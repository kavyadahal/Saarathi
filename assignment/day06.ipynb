# %% [markdown]
# # Day 6 Revision Summary — Functions & Comprehensions
#
# - Refactoring repeated/inline logic into reusable **functions** with parameters and `return` values (`celsius_to_f`, `grade`, `average`).
# - Variable-length positional arguments with `*args` (e.g. `average(*nums)` accepts any number of numbers).
# - **List comprehensions** as a concise alternative to a `for` loop + `.append()`, proven equivalent to the explicit loop form.
# - **Dict comprehensions** (`{w: len(w) for w in words}`) and **set comprehensions** (for deduplicating derived values like unique word lengths).
# - A tiny calculator module (`add`/`sub`/`mul`/`div`) demonstrates functions with a simple guard clause for division-by-zero, foreshadowing Day 7's error handling.
# - No shared/top-level "formulas" resource was referenced by this day's material; no separate homework folder was found in Drive for Day 6 — all material is in classwork.

# %% [markdown]
# ## Classwork Exercise 1 — Refactor into functions (`functions_practice.py`)
#
# **What's being asked:**
# Turn three pieces of logic into proper functions: `celsius_to_f(c)` converting Celsius to Fahrenheit, `grade(score)` returning a letter grade from a numeric score, and `average(*nums)` returning the mean of any number of arguments using `*args`. Call each and print the results; the source gives expected outputs: `celsius_to_f(30)` -> `86.0`, `grade(72)` -> `"B"`, `average(4, 9, 1, 6)` -> `5.0`.
#
# **Approach:**
# 1. Define `celsius_to_f(c)` returning `c * 9 / 5 + 32`.
# 2. Define `grade(score)` using an if/elif/else chain: A (>=80), B (>=60), C (>=40), else "Fail".
# 3. Define `average(*nums)` so it accepts any number of positional arguments, then return `sum(nums) / len(nums)`.
# 4. Call all three functions with the given sample inputs and `print()` each result.
# 5. Check your printed results against the expected values above before moving on.

# %%
"""
Day 6 - Exercise 1: Refactor into functions
Run with: python functions_practice.py
"""

# TODO: define celsius_to_f(c) -> float
#   formula: c * 9 / 5 + 32
def celsius_to_f(c):
    pass  # replace with your implementation


# TODO: define grade(score) -> str
#   A if score >= 80, B if >= 60, C if >= 40, else "Fail"
def grade(score):
    pass  # replace with your implementation


# TODO: define average(*nums) -> float using *args so it accepts any
#       number of positional numeric arguments
def average(*nums):
    pass  # replace with your implementation


# Call each and print the results - expected:
print(celsius_to_f(30))  # expected: 86.0
print(grade(72))  # expected: B
print(average(4, 9, 1, 6))  # expected: 5.0

# %% [markdown]
# ## Classwork Exercise 2 — Comprehensions (`comprehensions.py`)
#
# **What's being asked:**
# Practice list, dict, and set comprehensions: (1) build a list of even numbers from 1-20, (2) build a list of the lengths of a list of words, (3) build a dict mapping each word to its length, (4) rebuild #1 with a normal `for` loop and confirm the two lists are equal, and (5) as a stretch, build a **set** of the unique word lengths appearing in a sentence.
#
# **Approach:**
# 1. Use `[n for n in range(1, 21) if n % 2 == 0]` to get the evens list.
# 2. Use `[len(w) for w in words]` for the list of word lengths, where `words = ["ai", "ml", "rag", "llm"]`.
# 3. Use `{w: len(w) for w in words}` for the word -> length dict.
# 4. Rewrite the evens comprehension as an explicit `for` loop appending into a fresh list, then compare with `==` to the comprehension result (should print `True`).
# 5. Stretch: split a sentence into words and use a set comprehension `{len(w) for w in sentence.split()}` to get only the unique lengths.

# %%
"""
Day 6 - Exercise 2: Comprehensions
Run with: python comprehensions.py
"""

# TODO 1: even numbers 1..20 using a list comprehension
# evens = [n for n in range(1, 21) if ...]
# print(evens)

# TODO 2: lengths of each word in this list, using a list comprehension
words = ["ai", "ml", "rag", "llm"]
# lengths = [... for w in words]
# print(lengths)

# TODO 3: dict comprehension mapping word -> length
# word_lengths = {... : ... for w in words}
# print(word_lengths)

# TODO 4: rebuild #1 as a normal for loop into evens_loop, then confirm
#         evens_loop == evens (should print True)
# evens_loop = []
# for n in range(1, 21):
#     ...
# print(evens_loop == evens)

# STRETCH: unique word lengths from a sentence, using a set comprehension
sentence = "ai and ml power modern data tools"
# unique_lengths = {... for w in sentence.split()}
# print(unique_lengths)

# %% [markdown]
# ## Classwork Exercise 3 — Tiny calculator (`calculator.py`, buffer / stretch)
#
# **What's being asked:**
# Write four simple arithmetic functions — `add`, `sub`, `mul`, `div` — each taking two numbers. `div` must guard against division by zero by returning the string `"cannot divide by zero"` instead of raising an error. Sample calls given: `add(2, 3)` -> `5`, `sub(10, 4)` -> `6`, `mul(6, 7)` -> `42`, `div(20, 5)` -> `4.0`, `div(5, 0)` -> `"cannot divide by zero"`.
#
# **Approach:**
# 1. Define `add(a, b)` returning `a + b`.
# 2. Define `sub(a, b)` returning `a - b`.
# 3. Define `mul(a, b)` returning `a * b`.
# 4. Define `div(a, b)`: if `b == 0`, return the string `"cannot divide by zero"`; otherwise return `a / b`.
# 5. Call each function with the sample inputs and print the results, checking them against the expected values above.

# %%
"""
Day 6 - Exercise 3: Tiny calculator (buffer / stretch)
Run with: python calculator.py
"""

# TODO: define add, sub, mul, div.
#       div must guard against b == 0 by returning the string
#       "cannot divide by zero" instead of raising an error.
def add(a, b):
    pass  # replace with your implementation


def sub(a, b):
    pass  # replace with your implementation


def mul(a, b):
    pass  # replace with your implementation


def div(a, b):
    pass  # replace with your implementation


print(add(2, 3))  # expected: 5
print(sub(10, 4))  # expected: 6
print(mul(6, 7))  # expected: 42
print(div(20, 5))  # expected: 4.0
print(div(5, 0))  # expected: cannot divide by zero

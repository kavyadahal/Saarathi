# %% [markdown]
# # Day 5 Revision Summary — Week 1 Revision (Types, Strings, Loops, Collections)
#
# - Consolidation day covering everything from Days 1-4: variable types & operators, f-strings & conditionals, loops with the accumulate pattern, and dict/list/set collections.
# - The centerpiece is a single mini-project (student report card) that chains dict iteration, conditional grading, running best/worst tracking, and building a `set` of retakes — showing how Week 1's concepts combine in one real program.
# - `mixed_drills.py` trains a "predict before you run" habit: writing down what you expect a line to print *before* executing it, then comparing, which surfaces misconceptions directly.
# - A short "Cursor check" activity introduces responsible use of AI autocomplete: accept a suggestion only if you can explain it out loud first.
# - Closes Week 1 and previews Week 2: functions & comprehensions, type hints, error handling, file/JSON I/O, modules/OOP, and a first look at numpy/pandas.
# - No shared/top-level "formulas" resource was referenced by this day's material.

# %% [markdown]
# ## Classwork Exercise 1 — Student report card (`report_card.py`, ~25 min)
#
# **What's being asked:**
# Starting from the dict `scores = {"Math": 78, "Python": 92, "English": 55, "Science": 34}`, build a small program that: prints each subject/score neatly with an f-string, computes the class average to 1 decimal place, assigns a letter grade from that average, finds the best and worst subject by score, counts how many subjects passed (score >= 40), and — as a stretch — collects the subjects that must be retaken (score < 40) into a `set`. This exercise deliberately reuses every concept from Days 1-4 (dict, loop + accumulate, conditions, f-strings, operators, set).
#
# As a bonus, the source material suggests a "Cursor check": let an AI autocomplete tool (e.g. Cursor) suggest exactly one line of this program, and only accept it if you can explain out loud what it does — otherwise delete it and write it yourself.
#
# **Approach:**
# 1. Loop over `scores.items()`, printing each subject and score with an f-string (e.g. using field widths), and accumulate a running `total` as you go.
# 2. Compute `average = total / len(scores)` and print it formatted to 1 decimal place (`:.1f`).
# 3. Use an `if/elif/else` chain (strictest condition first) to turn the average into a grade: A (>=80), B (>=60), C (>=40), else "Needs work".
# 4. Track a running best/worst subject: initialize `best_score = -1` and `worst_score = 101` (values guaranteed to lose the first comparison), then loop again updating whichever tracker is beaten.
# 5. Loop once more (or reuse an earlier loop) to count how many scores are `>= 40`.
# 6. Stretch: build an empty `set()` and `.add()` any subject whose score is `< 40`, then print it.
# 7. Optional: try the Cursor check on one line and narrate why it's correct (or rewrite it if you can't).

# %%
"""
Day 5 - Exercise 1: Student report card (Week 1 mini project)
Run with: python report_card.py
"""

scores = {"Math": 78, "Python": 92, "English": 55, "Science": 34}

# TODO 1: loop over scores.items(), print "subject  score" with an f-string,
#         and accumulate a running total as you go.
total = 0
# for subject, score in scores.items():
#     ...

# TODO 2: compute the average (to 1 decimal place when printed) and print it.
# average = ...

# TODO 3: assign a grade from the average.
#   A if average >= 80, B if >= 60, C if >= 40, else "Needs work"
# grade = ...

# TODO 4: find the best and worst subject by score (track running best/worst).
# best, best_score = "", -1
# worst, worst_score = "", 101
# for subject, score in scores.items():
#     ...

# TODO 5: count how many subjects passed (score >= 40).
# passed = ...

# STRETCH: build a set of subjects that must be retaken (score < 40).
# retakes = set()
# ...
# print(f"Retakes: {retakes}")

# %% [markdown]
# ## Classwork Exercise 2 — Mixed drills (`mixed_drills.py`, ~12 min)
#
# **What's being asked:**
# Open `mixed_drills.py`, which contains a series of short snippets covering Day 1 (types/operators/truthiness), Day 2 (strings/f-strings/conditions), Day 3 (loops/accumulate/break-continue) and Day 4 (collections). For **each** line marked `# predict:`, write down your prediction of the output as a comment *before* running the file, then run it and compare. Getting a prediction wrong is the point — it tells you exactly what to revisit.
#
# **Approach:**
# 1. Open the file without running it first.
# 2. For every line ending in `# predict:`, replace/extend the comment with your guess of the printed value.
# 3. Only after all predictions are written, run `python mixed_drills.py`.
# 4. Compare actual output to your predictions line by line.
# 5. For any mismatch, look up the specific rule (integer division vs modulo, truthiness of `"0"`, string slicing, `continue` vs `break`, `dict.get` default, etc.) and write a one-line note of what you got wrong.

# %%
"""
Day 5 - Exercise 2: Mixed drills (all of Week 1)
Write your PREDICTION as a comment next to each line FIRST, then run:
    python mixed_drills.py
"""

# --- Day 1: types, operators, truthiness ---
print(7 // 2, 7 % 2, 2 ** 3)  # TODO predict:
print(bool(""), bool("0"), bool(0))  # TODO predict:

# --- Day 2: strings, f-strings, conditions ---
s = "Python"
print(f"{s[:2]}-{s[-1]}")  # TODO predict:
print("a,b,c".split(","))  # TODO predict:
x = 10
if x > 5 and x < 20:
    print("A")  # TODO predict: does this run?
else:
    print("B")

# --- Day 3: loops, accumulate, break/continue ---
total = 0
for i in range(1, 6):
    if i % 2 == 0:
        continue
    total += i
print(total)  # TODO predict:

n = 10
while n > 1:
    n = n // 2
print(n)  # TODO predict:

# --- Day 4: collections ---
words = "ai ml ai".split()
print(len(words), len(set(words)))  # TODO predict:

d = {"a": 1}
print(d.get("b", 0) + d["a"])  # TODO predict:

xs = [5, 3, 8]
xs.append(1)
xs.sort()
print(xs, sum(xs), max(xs))  # TODO predict:

# %% [markdown]
# ## Homework Exercise 1 — Rebuild one program per day from memory (~before Week 2)
#
# **What's being asked:**
# Without looking at your notes, rebuild one small program per day of Week 1: Day 1 "About Me" (variables + types), Day 2 a grade classifier (conditions + f-strings), Day 3 FizzBuzz (loops), and Day 4 a word counter (dicts). If you get stuck, don't peek at old code — write what you remember, run it, read the error message, and fix it. The source material calls debugging from an error message "the single most valuable skill of Week 1".
#
# **Approach:**
# 1. For "About Me": declare a handful of variables of different types (name: str, age: int, height: float, is_student: bool) and print them with an f-string.
# 2. For the grade classifier: take a numeric score and use if/elif/else to print a letter grade.
# 3. For FizzBuzz: loop from 1 to N, printing "Fizz" for multiples of 3, "Buzz" for multiples of 5, "FizzBuzz" for both, otherwise the number.
# 4. For the word counter: split a sentence into words and build a dict mapping each word to how many times it appears.
# 5. Run each snippet as you write it; if it errors, read the traceback's last line first, fix just that, and re-run before moving on.

# %%
"""
Day 5 - Homework Exercise 1: Rebuild one program per day, from memory.
No peeking at your old Day 1-4 files until after you've tried!
"""

# TODO Day 1 rebuild - "About Me": a few variables of different types,
#      printed with an f-string.
# name = ...
# age = ...
# height = ...
# is_student = ...
# print(f"...")

# TODO Day 2 rebuild - grade classifier: given a numeric score,
#      print a letter grade using if/elif/else.
# score = 72
# ...

# TODO Day 3 rebuild - FizzBuzz: loop 1..20 (inclusive), printing
#      "Fizz"/"Buzz"/"FizzBuzz"/the number as appropriate.
# for i in range(1, 21):
#     ...

# TODO Day 4 rebuild - word counter: split a sentence into words and
#      build a dict of word -> count.
# sentence = "ai and ml and ai again"
# counts = {}
# ...
# print(counts)

# %% [markdown]
# ## Other homework items (no code needed)
#
# - Finish `report_card.py` if it wasn't fully completed in class, including the retake-`set` stretch goal.
# - Work through `resources/week1_revision_sheet.md` and tick off every item in `resources/self_assessment.md`; any box left unticked becomes your agenda for the Sunday Open Classroom.
# - Commit your work: `git add .` then `git commit -m "week 1 complete"`.
# - Rest — Week 2 (functions, comprehensions, type hints, error handling, file/JSON I/O, modules/OOP, numpy/pandas) starts next.

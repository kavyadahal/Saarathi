# %% [markdown]
# # Day 7 Revision Summary — Type Hints & Error Handling
#
# - Adding **type hints** to function parameters and return values (including `list[float]`, and optional-style `str | None`) for clarity and editor/tooling support.
# - Using `try` / `except` to handle *expected* runtime errors (`ValueError`, `ZeroDivisionError`) instead of letting the program crash.
# - Defining and `raise`-ing a **custom exception class** (`DivByZeroError`) so a specific failure mode has its own name, instead of returning a sentinel value or string.
# - Writing "safe" wrapper functions that never crash on bad input — `safe_int`, `safe_div` — by catching the specific exception and returning a sensible fallback (`0`, `None`).
# - Bringing it together: a "bulletproof" calculator combining type hints + a custom exception + try/except in one program.
# - No shared/top-level "formulas" resource was referenced by this day's material.

# %% [markdown]
# ## Classwork Exercise 1 — Type your Day 6 functions (`typed_functions.py`)
#
# **What's being asked:**
# Take the Day 6 functions (`celsius_to_f`, `grade`, `average`) plus a new `total` function and add full type hints to parameters and return types. Also write a stretch function `find_name(names: list[str], target: str) -> str | None` that returns the matching name or `None` if not found. Expected outputs given: `celsius_to_f(30)` -> `86.0`, `grade(72)` -> `"B"`, `average([4, 9, 1, 6])` -> `5.0`, `total([1, 2, 3, 4])` -> `10`, `find_name(["ai", "ml"], "ml")` -> `"ml"`, `find_name(["ai", "ml"], "rag")` -> `None`.
#
# **Approach:**
# 1. Re-write `celsius_to_f(c: float) -> float` with the same formula as Day 6.
# 2. Re-write `grade(score: int) -> str` with the same if/elif/else chain.
# 3. Re-write `average(nums: list[float]) -> float` — note this version takes a single list argument (not `*args`).
# 4. Add `total(nums: list[int]) -> int` returning `sum(nums)`.
# 5. Write `find_name(names: list[str], target: str) -> str | None`: loop through `names`, return the name if it equals `target`, otherwise return `None` after the loop.
# 6. Call each function with the sample inputs and check the printed results against the expected values above.

# %%
"""
Day 7 - Exercise 1: Type your Day 6 functions
Run with: python typed_functions.py
"""

# TODO: add type hints to each function below and implement it.

def celsius_to_f(c: float) -> float:
    pass  # replace with your implementation


def grade(score: int) -> str:
    pass  # replace with your implementation


def average(nums: list[float]) -> float:
    pass  # replace with your implementation


def total(nums: list[int]) -> int:
    pass  # replace with your implementation


# STRETCH: returns a string OR None
def find_name(names: list[str], target: str) -> str | None:
    pass  # replace with your implementation


print(celsius_to_f(30))  # expected: 86.0
print(grade(72))  # expected: B
print(average([4, 9, 1, 6]))  # expected: 5.0
print(total([1, 2, 3, 4]))  # expected: 10
print(find_name(["ai", "ml"], "ml"))  # expected: ml
print(find_name(["ai", "ml"], "rag"))  # expected: None

# %% [markdown]
# ## Classwork Exercise 2 — Safe input parser (`safe_input.py`)
#
# **What's being asked:**
# Write `safe_int(text: str) -> int` that converts a string to an int, returning `0` instead of crashing if the string isn't a valid number. Write `safe_div(a: float, b: float) -> float | None` that returns `None` instead of crashing on division by zero. Expected outputs: `safe_int("42")` -> `42`, `safe_int("abc")` -> `0`, `safe_int("")` -> `0`, `safe_div(10, 2)` -> `5.0`, `safe_div(10, 0)` -> `None`.
#
# **Approach:**
# 1. Define `safe_int(text)`: inside a `try` block, `return int(text)`; in `except ValueError`, `return 0`.
# 2. Define `safe_div(a, b)`: inside a `try` block, `return a / b`; in `except ZeroDivisionError`, `return None`.
# 3. Call both functions with the sample inputs (valid number string, non-numeric string, empty string; a normal division and a division by zero) and print the results.
# 4. Confirm each printed value matches the expected output above.

# %%
"""
Day 7 - Exercise 2: Safe input parser
Run with: python safe_input.py
"""

# TODO: implement safe_int - convert text to int, return 0 on ValueError
def safe_int(text: str) -> int:
    pass  # use try/except ValueError


# TODO: implement safe_div - return a / b, or None on ZeroDivisionError
def safe_div(a: float, b: float) -> float | None:
    pass  # use try/except ZeroDivisionError


print(safe_int("42"))  # expected: 42
print(safe_int("abc"))  # expected: 0
print(safe_int(""))  # expected: 0

print(safe_div(10, 2))  # expected: 5.0
print(safe_div(10, 0))  # expected: None

# %% [markdown]
# ## Classwork Exercise 3 — Bulletproof calculator (`safe_calculator.py`, buffer / stretch)
#
# **What's being asked:**
# Combine type hints, a custom exception, and try/except into one program: define a `DivByZeroError(Exception)` class, then `add`, `mul`, and `divide` functions (all fully type-hinted), where `divide` raises `DivByZeroError` when `b == 0`. Call `divide(5, 0)` inside a `try`/`except DivByZeroError` block and print a handled message instead of crashing. Expected: `add(2, 3)` -> `5`, `mul(6, 7)` -> `42`, `divide(20, 5)` -> `4.0`, and `divide(5, 0)` handled to print `"Handled: cannot divide by zero"`.
#
# **Approach:**
# 1. Define `class DivByZeroError(Exception): pass`.
# 2. Define `add(a: float, b: float) -> float` and `mul(a: float, b: float) -> float`.
# 3. Define `divide(a: float, b: float) -> float`: if `b == 0`, `raise DivByZeroError("cannot divide by zero")`; otherwise return `a / b`.
# 4. Call `add` and `mul` directly and print results, then call `divide(20, 5)` directly and print it (no error expected).
# 5. Wrap a call to `divide(5, 0)` in `try`/`except DivByZeroError as e`, and in the except block print `f"Handled: {e}"`.

# %%
"""
Day 7 - Exercise 3: Bulletproof calculator (buffer / stretch)
Type hints + a custom exception + try/except.
Run with: python safe_calculator.py
"""

# TODO: define a custom exception for division by zero
class DivByZeroError(Exception):
    pass


def add(a: float, b: float) -> float:
    pass  # replace with your implementation


def mul(a: float, b: float) -> float:
    pass  # replace with your implementation


def divide(a: float, b: float) -> float:
    pass  # raise DivByZeroError("cannot divide by zero") if b == 0


print(add(2, 3))  # expected: 5
print(mul(6, 7))  # expected: 42
print(divide(20, 5))  # expected: 4.0

# TODO: call the risky one inside try/except and print a handled message
# try:
#     print(divide(5, 0))
# except DivByZeroError as e:
#     print(f"Handled: {e}")  # expected: Handled: cannot divide by zero

# %% [markdown]
# ## Homework Exercise 1 — Safe dictionary getter
#
# **What's being asked:**
# Write `safe_get(d: dict, key: str, default=None)` that returns `d[key]` if the key exists, otherwise `default` — implemented using `try` / `except KeyError` rather than the built-in `.get()` method, so you practise the try/except pattern directly.
#
# **Approach:**
# 1. Define `def safe_get(d: dict, key: str, default=None):`.
# 2. Inside a `try` block, `return d[key]`.
# 3. In the matching `except KeyError:` block, `return default`.
# 4. Test it against a small dict with both a present key and a missing key, and with a custom default value, to confirm both branches behave correctly.

# %%
"""
Day 7 - Homework Exercise 1: Safe dictionary getter
Implement with try/except KeyError (not .get()).
"""

# TODO: implement safe_get using try/except KeyError, NOT dict.get()
def safe_get(d: dict, key: str, default=None):
    pass  # try: return d[key] / except KeyError: return default


sample = {"a": 1, "b": 2}
print(safe_get(sample, "a"))  # expected: 1
print(safe_get(sample, "z"))  # expected: None
print(safe_get(sample, "z", default=0))  # expected: 0

# %% [markdown]
# ## Homework Exercise 2 — Predict the error, then handle it
#
# **What's being asked:**
# Given `values = ["10", "20", "oops", "40"]`, loop through the list, convert each entry to an `int`, and sum only the ones that successfully parse — using `try`/`except ValueError` so `"oops"` is skipped instead of crashing the program. The source material states the expected total is `70`.
#
# **Approach:**
# 1. Start with `total = 0` and `values = ["10", "20", "oops", "40"]`.
# 2. Loop over `values`; inside the loop, wrap the `int(value)` conversion in a `try` block.
# 3. If conversion succeeds, add the result to `total`.
# 4. In `except ValueError:`, do nothing (or print a skip message) so the loop continues to the next value instead of crashing.
# 5. After the loop, print `total` and confirm it equals `70`.

# %%
"""
Day 7 - Homework Exercise 2: Predict the error, then handle it
Expected total: 70
"""

values = ["10", "20", "oops", "40"]

# TODO: loop the list, convert each to int, and sum only the ones that parse.
# Use try/except ValueError so "oops" is skipped, not fatal.
total = 0
# for value in values:
#     try:
#         ...
#     except ValueError:
#         ...

print(total)  # expected: 70

# %% [markdown]
# ## Other homework items (no code needed)
#
# - Finish `safe_calculator.py` (the bulletproof calculator) if it wasn't completed in class, including the custom `DivByZeroError`.
# - Go back through your Week 1 and Day 6 files and add type hints to every function — the source notes this is "the fastest way to make them click".
# - Commit your work: `git add .` then `git commit -m "day 7"`.
# - Preview for Day 8: files & JSON — reading/writing text with `with open(...)`, `pathlib` for paths, and `json.dumps`/`json.loads` (the format every API and LLM tool call uses).

# %% [markdown]
# # Day 11 Revision Summary — pandas: merge, groupby & missing data (reconstructed — no Day 11 files found in Drive)
#
# **Important caveat:** Day 11's Google Drive folder (`1hhep4ULbzBgckZWt6gyodGdc24LGN8h5`) contains four subfolders — `resources`, `classwork`, `slides`, `homework` — and **all four were empty** at the time of writing (confirmed by repeated `parentId` searches, `get_file_metadata` on each subfolder, and full-corpus `title`/`fullText` searches for `"week3_day1"`, `"groupby"`, `"merge"`, `"wrangl"`, `"isna"` across the whole Drive — none matched). No classwork, homework, or slide-deck content has been uploaded for this day.
#
# The bullets below are **reconstructed only** from the "Recap Day 11" warm-up slide inside Day 12's deck (`week3_day2_sql_splits.html`), which is the sole surviving textual trace of what Day 11 covered:
#
# - Day 11 (Week 3 · Day 1) evidently covered **combining tables** with `pd.merge(...)` on a shared key — a prerequisite the Day 12 recap explicitly calls back to ("why do you merge before you can group 'score per city'?").
# - **Split-apply-combine** aggregation via `df.groupby(col)["value"].mean()` (or similar) to summarize data by category.
# - A **boolean-filter gotcha**: combining multiple conditions on a DataFrame needs `&` / `|` with each condition parenthesized — plain `and`/`or` does not work element-wise on a pandas Series.
# - Detecting missing data with `df.isna().sum()` to count nulls per column, presumably ahead of any modelling work.
# - No exercise-level detail (specific files, exact instructions, time estimates) could be verified for Day 11 — only the four bullet-point topics above are attested by the Day 12 recap slide.

# %% [markdown]
# ## Other homework items (no code needed)
#
# - No classwork or homework items could be identified for Day 11 — its Drive folders (`classwork`, `homework`, `slides`, `resources`) contained no files. If material is later uploaded to Drive, this notebook should be regenerated from it rather than from the Day 12 recap alone.

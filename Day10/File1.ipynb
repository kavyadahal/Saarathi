# %%
import json
import numpy as np

# %%
def  f(a,b=2,*args):
    return a*b+len(args)
print (f(3))
print(f(3,3))
print(f(3,3,9,9))

def g(x):
    print(x*2)
result = g(5)
print(result)
# Out:
# 6
# 9
# 11
# 10
# None

# %%
print([n for n in range(6) if n%2==0])
print({w:len(w) for w in ["ai","rag"]})
# Out:
# [0, 2, 4]
# {'ai': 2, 'rag': 3}

# %%
def double(x:int)->int:
    return x*2
print(double("ab"))
# Out:
# abab

# %%
try:
    n = int("3.5")
    print(n)
except ValueError as e:
    print("Caught:",type(e).__name__)
# Out:
# Caught: ValueError

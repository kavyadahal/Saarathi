# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest , f_classif
from sklearn.datasets import load_wine
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

# %%
X , y = load_wine(return_X_y=True)
model = LogisticRegression(max_iter=5000)

# %%
#Leaky
X_sel = SelectKBest(f_classif , k = 5).fit_transform(X,y)
leaky = cross_val_score(model , X_sel , y , cv =5)

# %%
#pipeline:
pipe = Pipeline([
    ("select",SelectKBest(f_classif,k=20)),
    ("clf",model)
])
honest = cross_val_score(pipe,X ,y , cv = 5)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:782: UserWarning: k=20 is greater than n_features=13. All the features will be returned.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:782: UserWarning: k=20 is greater than n_features=13. All the features will be returned.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:782: UserWarning: k=20 is greater than n_features=13. All the features will be returned.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:782: UserWarning: k=20 is greater than n_features=13. All the features will be returned.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:782: UserWarning: k=20 is greater than n_features=13. All the features will be returned.
#   warnings.warn(

# %%
print(leaky.mean(),honest.mean())
# Out:
# 0.9720634920634922 0.961111111111111

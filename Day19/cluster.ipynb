# %%
from data_gen import make_deliveries
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
#Take only numerical Columns for clustering:
df ,_=make_deliveries() 
X = df[["distance" , "prep" , "hour"]]
X
# Out:
#       distance       prep  hour
# 0    15.705165  30.850314    21
# 1     9.338690  16.100361    21
# 2    17.313360  36.150681    19
# 3    14.249993  25.784069    10
# 4     2.789370   9.410922    12
# ..         ...        ...   ...
# 795   7.583094  28.846532    13
# 796   1.361649  11.717241     8
# 797   4.144267  11.141179    20
# 798  14.778483  33.419587    18
# 799  14.453733  14.264910    15
#
# [800 rows x 3 columns]

# %%
X_scaled = StandardScaler().fit_transform(X)
X_scaled
# Out:
# array([[ 0.96292252,  0.80211091,  1.38290408],
#        [-0.19124394, -0.6472696 ,  1.38290408],
#        [ 1.25446934,  1.32294305,  0.91845267],
#        [ 0.699117  ,  0.30428451, -1.17157869]])
